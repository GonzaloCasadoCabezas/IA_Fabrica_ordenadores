# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Configuración visualización
# %matplotlib inline
plt.style.use('ggplot')
sns.set_palette("husl")

# %%
df = pd.read_csv("./simulation_results_20250404_174004.csv")

# %%
print("Dimensiones del dataset:", df.shape)
print("\nPrimeras filas:")
display(df.head())

# Estadisticas descriptivas
print("\nEstadisticas descriptivas:")
display(df.describe(include='all').round(2))
# Out:
# Dimensiones del dataset: (5600, 10)
#
# Primeras filas:
#       Component            Name  Start_Time   End_Time  Total_Time  \
# 0     Processor     Processor_0           0   5.190087    5.190087
# 1   Motherboard   Motherboard_3           0   9.000000    9.000000
# 2     Processor     Processor_0           0  15.964707   15.964707
# 3     Processor     Processor_0           0  25.992646   25.992646
# 4  GraphicsCard  GraphicsCard_9           0  27.000000   27.000000
#
#    Assembly_Time  Main_Assembly_Time  Transport_Time   Status  Transport_Delay
# 0              0                   2               2  Success        -1.190087
# 1              3                   6               2  Success         2.000000
# 2              0                   6               3  Success        -6.964707
# 3              0                   5               4  Success       -16.992646
# 4              9                   5               3  Success       -10.000000
# Estadisticas descriptivas:
#         Component         Name  Start_Time  End_Time  Total_Time  \
# count        5600         5600      5600.0   5600.00     5600.00
# unique          8          800         NaN       NaN         NaN
# top     Processor  Processor_0         NaN       NaN         NaN
# freq          700            7         NaN       NaN         NaN
# mean          NaN          NaN         0.0  29356.36    29356.36
# std           NaN          NaN         0.0  16979.83    16979.83
# min           NaN          NaN         0.0      5.19        5.19
# 25%           NaN          NaN         0.0  14701.52    14701.52
# 50%           NaN          NaN         0.0  29347.73    29347.73
# 75%           NaN          NaN         0.0  44028.78    44028.78
# max           NaN          NaN         0.0  58752.61    58752.61
#
#         Assembly_Time  Main_Assembly_Time  Transport_Time   Status  \
# count         5600.00              5600.0          5600.0     5600
# unique            NaN                 NaN             NaN        1
# top               NaN                 NaN             NaN  Success
# freq              NaN                 NaN             NaN     5600
# mean            49.50                 4.5             5.0      NaN
# std             28.87                 1.5             2.0      NaN
# min              0.00                 2.0             2.0      NaN
# 25%             24.75                 3.0             3.0      NaN
# 50%             49.50                 5.0             5.0      NaN
# 75%             74.25                 6.0             7.0      NaN
# max             99.00                 7.0             8.0      NaN
#
#         Transport_Delay
# count           5600.00
# unique              NaN
# top                 NaN
# freq                NaN
# mean          -29297.36
# std            16952.41
# min           -58645.61
# 25%           -43977.53
# 50%           -29296.23
# 75%           -14666.77
# max                2.00

# %%
# Tiempos de procesamiento
plt.figure(figsize=(12,6))
sns.boxplot(data=df, x='Component', y='Total_Time')
plt.title('Distribución de tiempos totales por componente')
plt.xticks(rotation=45)
plt.ylabel('Tiempo Total')
plt.show()

# %%
# Retrasos en transporte
plt.figure(figsize=(10,5))
sns.histplot(df['Transport_Delay'], bins=20, kde=True)
plt.title('Distribución de retrasos en trasnsporte')
plt.xlabel('Retraso (unidades de tiempo)')
plt.show()

# %%
components_stats = df.groupby('Component').agg({'Total_Time': ['mean', 'std', 'min', 'max'], 'Transport_Delay': ['mean', 'median'], 'Status': lambda x: (x == 'Success').mean()}).round(2)

components_stats.columns = ['_'.join(col).strip() for col in component_stats.columns.values]
components_stats = components_stats.rename(columns={'Status_<lambda>': 'Success_rate'})

print("Estadísticas por componentes:")
display(components_stats.sort_values('Total_Time_mean', ascending = False))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 components_stats = df.groupby('Component').agg({'Total_Time': ['mean', 'std', 'min', 'max'], 'Transport_Delay': ['mean', 'median'], 'Status': lambda x: (x == 'Success').mean()}).round(2)
# ----> 3 components_stats.columns = ['_'.join(col).strip() for col in component_stats.columns.values]
#       4 components_stats = components_stats.rename(columns={'Status_<lambda>': 'Success_rate'})
#       6 print("Estadísticas por componentes:")
#
# NameError: name 'component_stats' is not defined
